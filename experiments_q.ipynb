# %%
pip install pandas

# %%
pip install torch torchvision torchaudio

# %%
pip install transformers

# %%
pip install tensorflow

# %%
pip install sentencepiece

# %%
pip install datasets

# %%
import pandas as pd
import transformers
# Out:
# 2023-03-02 08:06:15.788579: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained("t5-small")
model = T5ForConditionalGeneration.from_pretrained("t5-small")

input_ids = tokenizer("The <extra_id_0> walks in <extra_id_1> park", return_tensors="pt").input_ids
labels = tokenizer("<extra_id_0> cute dog <extra_id_1> the <extra_id_2>", return_tensors="pt").input_ids

# the forward function automatically creates the correct decoder_input_ids
loss = model(input_ids=input_ids, labels=labels).loss
loss.item()

# %%
import numpy as np
import tensorflow as tf
from transformers import T5ForConditionalGeneration, TFT5ForConditionalGeneration, T5Tokenizer, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("t5-small")
#model = TFT5ForConditionalGeneration.from_pretrained("t5-small")
model = T5ForConditionalGeneration.from_pretrained('t5-small')
#tokenizer = T5Tokenizer.from_pretrained('t5-small')

# Count the number of zero-valued parameters in the model
total_params = 0
num_zeros = 0
for param in model.parameters():
    total_params += param.numel()
    num_zeros += (param == 0).sum().item()

# Calculate the sparsity ratio
sparsity_ratio = num_zeros / total_params

print(f"Sparsity ratio: {sparsity_ratio:.4f}")
# Out:
# Sparsity ratio: 0.0000

# %%
print(model)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 512)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 8)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
# ...

# %%
import tensorflow as tf
from transformers import TFAutoModelForSeq2SeqLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("t5-small")
model = TFAutoModelForSeq2SeqLM.from_pretrained("t5-small")
# Out:
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at t5-small.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %%
input_str = "summarize: As transformers get larger and more powerful, interpreting them becomes more difficult, while the\
urgency to deploy them heightens. Without a robust interpretation of transformers, it is difficult to\
tell when they will fail, or act harmfully in the real world (see, e.g., Bing’s chat bot recently deployed\
in beta). It is crucial to better understand what hierarchical structures of concepts these models\
learn, and sparsity provides a route to that. Instead of all neurons firing at once, clear patterns of\
nonzero weights emerge consistently across Transformer architectures – which we aim to investigate.\
The main goal of our project is to explore sparsity in the T5 transformer model family using ReLU\
activation. As discussed in our paper review, many of these models contain layers with only a few\
active neurons, so we intend to probe these models in an attempt to understand what exactly these\
sparse features may be capturing."
input_ids = tokenizer(input_str, return_tensors="tf").input_ids
outputs = model.generate(input_ids=input_ids)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# a robust interpretation of transformers becomes difficult, while theurgency to deploy them height
